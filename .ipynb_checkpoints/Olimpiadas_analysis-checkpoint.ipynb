# %%
import seaborn as sns
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
from scipy import stats
import re

# %%
ruta_carpeta = r"C:\Users\david\Downloads"   # 
archivo = "OLIMPIADAS_2.csv"
ruta = os.path.join(ruta_carpeta, archivo)
df = pd.read_csv(ruta, encoding="utf-8", sep=None, engine="python")
print(len(df))
# Out:
# 1705

# %% [markdown]
# # Preprocesado
#
# - Marca temporal
# - Cálculo de la nota
# - Eliminar actuaciones con >5 puntos
# - Elimniar actuaciones con <5 votos

# %%
# 1️⃣ Limpiar espacios raros y caracteres invisibles
df['Marca temporal'] = df['Marca temporal'].str.replace('\xa0', ' ', regex=False).str.strip()
# 2️⃣ Convertir a formato datetime (detecta la hora y zona)
df['Marca temporal'] = pd.to_datetime(df['Marca temporal'], errors="coerce", utc=True)
# 3️⃣ Quitar zona horaria y quedarte solo con la fecha
df['Marca temporal'] = df['Marca temporal'].dt.tz_convert(None).dt.date
# 4️⃣ (Opcional) Renombrar la columna si quieres quitar las comillas
df = df.rename(columns={'Marca temporal': "fecha"})
# Out:
# C:\Users\david\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname CET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
#Nombres y actuaciones
# --- 1) Limpieza previa de la cadena ---
def _preclean_name(s: str) -> str:
    if pd.isna(s):
        return s
    s = str(s)
    # quitar comillas, backticks y dobles espacios
    s = re.sub(r'["“”\'`]+', '', s).strip()
    s = re.sub(r'\s+', ' ', s)
    # quitar puntos tras iniciales (e.g., "B." -> "B")
    s = re.sub(r'\b([A-Za-z])\.\b', r'\1', s)
    return s

df["Actuante"] = df["Actuante"].apply(_preclean_name)

# --- 2) Diccionario de equivalencias (canónicos a tu gusto) ---
# Nota: elegimos como nombre canónico el de la derecha.
equivalencias = {
    "Sergio G": "Sergio",
    "David B": "David Bestué",
    "Alfredo A": "Alfredo Alvarez",
    "Juan M": "Juan Martinez",
    "Juan Mtnez": "Juan Martinez",
    "Jordi Martí": "Jordi Marti",
    "Jordi Marti": "Jordi Marti",
    "Albert F": "Albert Farriol",
    "Ferran Homar": "Ferran Homar",
    "Ferran H": "Ferran Homar",
    "Alfredo Jauma": "Alfredo Jauma",
    "Alfredo J": "Alfredo Jauma",
    "Lluis": "Lluis Garcia",
    "Eduard": "Edu A",
    "Amilcar": "Amílcar",
    
}

# Para robustez: mapeo case-insensitive
equiv_ci = {k.casefold(): v for k, v in equivalencias.items()}

def _map_equiv(s: str) -> str:
    if pd.isna(s):
        return s
    return equiv_ci.get(s.casefold(), s)

df["Actuante"] = df["Actuante"].apply(_map_equiv)

# (Opcional) verifica cambios aplicados
antes = set(equivalencias.keys())
despues = set(equivalencias.values())
print("Ejemplos unificados presentes:",
      sorted(set(df["Actuante"]).intersection(despues)))
# Out:
# Ejemplos unificados presentes: ['Albert Farriol', 'Alfredo Alvarez', 'Alfredo Jauma', 'Amílcar', 'David Bestué', 'Edu A', 'Ferran Homar', 'Jordi Marti', 'Juan Martinez', 'Lluis Garcia', 'Sergio']

# %%
# Asegura que 'fecha' es solo fecha (sin hora) y ordenable
df["fecha"] = pd.to_datetime(df["fecha"], errors="coerce").dt.date

# Guarda el nombre original si quieres conservarlo
df["actuante_original"] = df["Actuante"]

# Ranking de fechas por actuante (1,2,3,...) — mismos días comparten el mismo número
df["n_actuacion"] = (
    df.groupby("Actuante")["fecha"]
      .transform(lambda s: pd.Series(s).rank(method="dense").astype(int))
)

# Renombra: primer día sin sufijo; a partir del segundo, _2, _3, ...
df["Actuante"] = np.where(
    df["n_actuacion"] == 1,
    df["Actuante"],
    df["Actuante"] + "_" + df["n_actuacion"].astype(str)
)

df = df.drop(columns=["n_actuacion"])

# %%
def calcular_nota(df: pd.DataFrame) -> pd.DataFrame:
    """
    Añade una columna 'nota' ponderando las cinco preguntas:
      - Imposibilidad del efecto: 30%
      - Presentación y charla: 30%
      - Método: 10%
      - Originalidad: 10%
      - Ejecución: 20%
    La nota resultante queda en la misma escala que las puntuaciones originales (1–10).
    """

    pesos = {
        '¿Qué te ha parecido la imposibilidad del efecto realizado?': 0.30,
        '¿Qué te han parecido la presentación y la charla?': 0.30,
        '¿Qué te ha parecido el método?': 0.10,
        '¿Qué te ha parecido la originalidad del juego?': 0.10,
        '¿Qué te ha parecido la ejecución del juego?': 0.20
    }

    # Asegurar tipo numérico
    for col in pesos.keys():
        df[col] = pd.to_numeric(df[col], errors='coerce')

    # Calcular nota ponderada
    df["nota"] = sum(df[col] * peso for col, peso in pesos.items())

    return df

# %%
df = calcular_nota(df)
df
# Out:
#            fecha         Actuante  \
# 0     2024-03-04           Enigma
# 1     2024-03-04       Xavi Soler
# 2     2024-03-04           Enigma
# 3     2024-03-04           Enigma
# 4     2024-03-04           Enigma
# ...          ...              ...
# 1700  2025-11-03  Albert Farriols
# 1701  2025-11-03  Albert Farriols
# 1702  2025-11-03  Albert Farriols
# 1703  2025-11-03   David Bestué_6
# 1704  2025-11-03  Albert Farriols
#
#       ¿Qué te ha parecido la imposibilidad del efecto realizado?  \
# 0                                                     3
# 1                                                     4
# 2                                                    10
# 3                                                     7
# 4                                                     5
# ...                                                 ...
# 1700                                                  4
# 1701                                                  3
# 1702                                                  4
# 1703                                                  5
# 1704                                                  4
#
#       ¿Qué te han parecido la presentación y la charla?  \
# 0                                                     7
# 1                                                     6
# 2                                                    10
# 3                                                     8
# 4                                                     9
# ...                                                 ...
# 1700                                                  4
# 1701                                                  3
# 1702                                                  4
# 1703                                                  5
# 1704                                                  4
#
#       ¿Qué te ha parecido el método?  \
# 0                                  3
# 1                                  1
# 2                                 10
# 3                                  7
# 4                                  5
# ...                              ...
# 1700                               4
# 1701                               2
# 1702                               4
# 1703                               5
# 1704                               4
#
#       ¿Qué te ha parecido la originalidad del juego?  \
# 0                                                  5
# 1                                                  2
# 2                                                 10
# 3                                                  7
# 4                                                  5
# ...                                              ...
# 1700                                               4
# 1701                                               3
# 1702                                               5
# 1703                                               5
# 1704                                               3
#
#       ¿Qué te ha parecido la ejecución del juego? actuante_original  nota
# 0                                               5            Enigma   4.8
# 1                                               6        Xavi Soler   4.5
# 2                                              10            Enigma  10.0
# 3                                               7            Enigma   7.3
# 4                                               4            Enigma   6.0
# ...                                           ...               ...   ...
# 1700                                            4   Albert Farriols   4.0
# 1701                                            3   Albert Farriols   2.9
# 1702                                            5   Albert Farriols   4.3
# 1703                                            5      David Bestué   5.0
# 1704                                            4   Albert Farriols   3.9
#
# [1705 rows x 9 columns]

# %%
# Columnas de interés
cols = [
    '¿Qué te ha parecido la imposibilidad del efecto realizado?',
    '¿Qué te han parecido la presentación y la charla?',
    '¿Qué te ha parecido el método?',
    '¿Qué te ha parecido la originalidad del juego?',
    '¿Qué te ha parecido la ejecución del juego?',
    'nota'
]

# Nombres más legibles para el título de cada subplot
nombres = [
    'Imposibilidad del efecto',
    'Presentación y charla',
    'Método',
    'Originalidad del juego',
    'Ejecución del juego',
    'Nota ponderada'
]

# Estilo general
sns.set_theme(style="whitegrid", font_scale=1.1)

fig, axes = plt.subplots(2, 3, figsize=(15, 8), sharey=True)
axes = axes.flatten()

for i, col in enumerate(cols):
    sns.histplot(
        df[col].dropna(),
        bins=10,
        kde=True,
        color=sns.color_palette("viridis", 6)[i],
        ax=axes[i]
    )
    axes[i].set_title(nombres[i], fontsize=12, weight="bold")
    axes[i].set_xlim(0.5, 10.5)
    axes[i].set_xticks(range(1, 11))
    axes[i].set_xlabel("Puntuación (1–10)")
    axes[i].set_ylabel("Frecuencia")

plt.suptitle("Distribución de puntuaciones por condición", fontsize=16, weight="bold", y=1.02)
plt.tight_layout()
plt.show()

# %%
# Columnas a comprobar (las de puntuaciones + la nota)
cols = [
    '¿Qué te ha parecido la imposibilidad del efecto realizado?',
    '¿Qué te han parecido la presentación y la charla?',
    '¿Qué te ha parecido el método?',
    '¿Qué te ha parecido la originalidad del juego?',
    '¿Qué te ha parecido la ejecución del juego?']

# Convertir a numérico por seguridad
for c in cols:
    df[c] = pd.to_numeric(df[c], errors='coerce')

# 1️⃣ Encontrar actuantes con alguna puntuación > 5
actuantes_erroneos = df.loc[df[cols].gt(5).any(axis=1), "Actuante"].unique()

print("🔍 Actuantes con valores fuera de rango (eliminados):")
print(actuantes_erroneos)

# 2️⃣ Eliminar todas las filas de esos actuantes
df = df[~df["Actuante"].isin(actuantes_erroneos)].copy()

# 3️⃣ Verificar
print(f"✅ DataFrame limpio: {df.shape[0]} filas restantes.")
# Out:
# 🔍 Actuantes con valores fuera de rango (eliminados):
# ['Enigma' 'Xavi Soler' 'Samu' 'Churrimongui' 'Jaume Cercós'
#  'Albert Farriol']
# ✅ DataFrame limpio: 1590 filas restantes.

# %%
# Columnas de interés
cols = [
    '¿Qué te ha parecido la imposibilidad del efecto realizado?',
    '¿Qué te han parecido la presentación y la charla?',
    '¿Qué te ha parecido el método?',
    '¿Qué te ha parecido la originalidad del juego?',
    '¿Qué te ha parecido la ejecución del juego?',
    'nota'
]

# Nombres más legibles para el título de cada subplot
nombres = [
    'Imposibilidad del efecto',
    'Presentación y charla',
    'Método',
    'Originalidad del juego',
    'Ejecución del juego',
    'Nota ponderada'
]

# Estilo general
sns.set_theme(style="whitegrid", font_scale=1.1)

fig, axes = plt.subplots(2, 3, figsize=(15, 8), sharey=True)
axes = axes.flatten()

for i, col in enumerate(cols):
    sns.histplot(
        df[col].dropna(),
        bins=10,
        kde=True,
        color=sns.color_palette("viridis", 6)[i],
        ax=axes[i]
    )
    axes[i].set_title(nombres[i], fontsize=12, weight="bold")
    axes[i].set_xlim(0.5, 5.5)
    axes[i].set_xticks(range(1, 6))
    axes[i].set_xlabel("Puntuación (1–5)")
    axes[i].set_ylabel("Frecuencia")

plt.suptitle("Distribución de puntuaciones por condición", fontsize=16, weight="bold", y=1.02)
plt.tight_layout()
plt.show()

# %%
df["Actuante"] = df["actuante_original"]
df["Actuante"] = df["Actuante"].apply(_preclean_name)
# Asegura que 'fecha' es solo fecha (sin hora) y ordenable
df["fecha"] = pd.to_datetime(df["fecha"], errors="coerce").dt.date
# Ranking de fechas por actuante (1,2,3,...) — mismos días comparten el mismo número
df["n_actuacion"] = (
    df.groupby("Actuante")["fecha"]
      .transform(lambda s: pd.Series(s).rank(method="dense").astype(int))
)

# Renombra: primer día sin sufijo; a partir del segundo, _2, _3, ...
df["Actuante"] = np.where(
    df["n_actuacion"] == 1,
    df["Actuante"],
    df["Actuante"] + "_" + df["n_actuacion"].astype(str)
)

df = df.drop(columns=["n_actuacion"])

# %%
#Contar cuántas puntuaciones tiene cada actuación (Actuante con sufijo)
conteos_actuaciones = df["Actuante"].value_counts()

# Identificar las actuaciones con menos de 5 puntuaciones
actuaciones_filtrar = conteos_actuaciones[conteos_actuaciones < 5].index.tolist()

print("🔍 Actuaciones con menos de 5 puntuaciones (se eliminarán):")
print(actuaciones_filtrar)

# (opcional) guardar las actuaciones descartadas
df_descartadas = df[df["Actuante"].isin(actuaciones_filtrar)].copy()

# Filtrar el DataFrame principal
df = df[~df["Actuante"].isin(actuaciones_filtrar)].copy()

print(f"✅ DataFrame limpio: {df['Actuante'].nunique()} actuaciones restantes, {df.shape[0]} filas totales.")
# Out:
# 🔍 Actuaciones con menos de 5 puntuaciones (se eliminarán):
# ['Xavi Soler_3', 'Albert Farriol', 'Toni Cachadiña_4', 'Jaume Cercós', 'Jaume Cercós_3', 'Shori_3', 'Alexander Main_3', 'David Valencia_3', 'David Bestué_3', 'Manuel Sta Maria', 'Xavi Soler']
# ✅ DataFrame limpio: 99 actuaciones restantes, 1579 filas totales.

# %%
df["Actuante"] = df["actuante_original"]
df["Actuante"] = df["Actuante"].apply(_preclean_name)
# Asegura que 'fecha' es solo fecha (sin hora) y ordenable
df["fecha"] = pd.to_datetime(df["fecha"], errors="coerce").dt.date
# Ranking de fechas por actuante (1,2,3,...) — mismos días comparten el mismo número
df["n_actuacion"] = (
    df.groupby("Actuante")["fecha"]
      .transform(lambda s: pd.Series(s).rank(method="dense").astype(int))
)

# Renombra: primer día sin sufijo; a partir del segundo, _2, _3, ...
df["Actuante"] = np.where(
    df["n_actuacion"] == 1,
    df["Actuante"],
    df["Actuante"] + "_" + df["n_actuacion"].astype(str)
)

df = df.drop(columns=["n_actuacion"])

# %%
print(len(df))
# Out:
# 1579

# %%
df.head()
# Out:
#           fecha Actuante  \
# 118  2024-04-08  Michele
# 119  2024-04-08  Michele
# 120  2024-04-08  Michele
# 121  2024-04-08  Michele
# 122  2024-04-08  Michele
#
#      ¿Qué te ha parecido la imposibilidad del efecto realizado?  \
# 118                                                  3
# 119                                                  4
# 120                                                  4
# 121                                                  4
# 122                                                  4
#
#      ¿Qué te han parecido la presentación y la charla?  \
# 118                                                  3
# 119                                                  4
# 120                                                  3
# 121                                                  4
# 122                                                  3
#
#      ¿Qué te ha parecido el método?  \
# 118                               2
# 119                               4
# 120                               3
# 121                               4
# 122                               4
#
#      ¿Qué te ha parecido la originalidad del juego?  \
# 118                                               3
# 119                                               4
# 120                                               4
# 121                                               4
# 122                                               3
#
#      ¿Qué te ha parecido la ejecución del juego? actuante_original  nota
# 118                                            4           Michele   3.1
# 119                                            4           Michele   4.0
# 120                                            3           Michele   3.4
# 121                                            4           Michele   4.0
# 122                                            3           Michele   3.4

# %% [markdown]
# # Análisis de puntuaciones

# %%
# --- 1. Definir pesos y añadir la columna 'nota' ---
pesos = {
    '¿Qué te ha parecido la imposibilidad del efecto realizado?': 0.30,
    '¿Qué te han parecido la presentación y la charla?': 0.30,
    '¿Qué te ha parecido el método?': 0.10,
    '¿Qué te ha parecido la originalidad del juego?': 0.10,
    '¿Qué te ha parecido la ejecución del juego?': 0.20
}

for col in pesos.keys():
    df[col] = pd.to_numeric(df[col], errors="coerce")

df["nota"] = sum(df[col] * peso for col, peso in pesos.items())

# --- 2. Calcular medias e IC95% para cada condición ---
condiciones = list(pesos.keys()) + ["nota"]
estadisticas = []

for col in condiciones:
    valores = df[col].dropna()
    n = len(valores)
    media = valores.mean()
    sem = stats.sem(valores)
    ci95 = sem * stats.t.ppf((1 + 0.95) / 2., n - 1)
    estadisticas.append({
        "condición": col,
        "media": media,
        "ci95": ci95
    })

df_plot = pd.DataFrame(estadisticas)

# --- 3. Limpiar nombres para el gráfico ---
df_plot["condición"] = (
    df_plot["condición"]
    .str.replace("¿Qué te ha parecido ", "", regex=False)
    .str.replace("¿Qué te han parecido ", "", regex=False)
    .str.replace("del ", "", regex=False)
    .str.replace("la ", "", regex=False)
    .str.replace("el ", "", regex=False)
    .str.replace("?", "", regex=False)
    .str.strip()
    .str.capitalize()
)
df_plot.loc[df_plot["condición"] == "Nota", "condición"] = "Nota ponderada"


colores = ["lightblue" if cond != "Nota ponderada" else "lightcoral" for cond in df_plot["condición"]]


# --- 4. Plot ---
sns.set_theme(style="whitegrid", font_scale=1.1)
plt.figure(figsize=(10, 5))

ax = sns.barplot(
    data=df_plot,
    x="condición",
    y="media",
    palette=colores,
    ci=None
)

    

def limpiar_nombre(txt):
    return (txt.replace("¿Qué te ha parecido ", "")
               .replace("¿Qué te han parecido ", "")
               .replace("del ", "")
               .replace("la ", "")
               .replace("el ", "")
               .replace("?", "")
               .strip()
               .capitalize())

# orden de x tal y como aparece en tu barplot
orden_x = list(df_plot["condición"])

# para cada condición, calcula la media por actuante y plotea puntos transparentes
for i, col in enumerate(list(pesos.keys()) + ["nota"]):
    medias_act = (
        df.groupby("Actuante")[col]
          .mean()
          .dropna()
          .values
    )
    # un poco de jitter horizontal para que no se solapen
    x_jitter = np.random.normal(loc=i, scale=0.06, size=len(medias_act))
    ax.scatter(
        x_jitter,
        medias_act,
        s=30,
        facecolors='grey',     # relleno transparente
        edgecolors='none',    # borde visible
        alpha=0.35,
        linewidths=1,
        zorder=3
    )

# opcional: que los puntos nunca queden tapados por las barras
for bar in ax.patches:
    bar.set_zorder(1)
    

    
# Añadir barras de error 95%
ax.errorbar(
    x=np.arange(len(df_plot)),
    y=df_plot["media"],
    yerr=df_plot["ci95"],
    fmt="none",
    ecolor="black",
    elinewidth=1.5,
    capsize=5
)

    
    
    
# Añadir texto con las medias
for i, row in df_plot.iterrows():
    ax.text(i, row["media"] + 0.4, f"{row['media']:.1f}",
            ha="center", va="bottom", fontsize=14, color="black")
    
    
    
    
    
# Ajustes estéticos
ax.set_title("Puntuación media", fontsize=15, weight="bold")
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("Puntuación media (1–5)", fontsize=12)
ax.set_ylim(0, 6)
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_12604\3964566277.py:55: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(

# %% [markdown]
# # Análisis individual

# %%
df['Actuante_base'] = df['Actuante'].str.replace(r'_\d+$', '', regex=True)

def fechas_unicas_str(s):
    # Convierte a datetime (por si vienen como date/str), elimina NaT, ordena y formatea
    s = pd.to_datetime(s, errors='coerce').dropna()
    if s.empty:
        return ''
    return ', '.join(sorted(s.dt.strftime('%Y-%m-%d').unique()))

tabla = (
    df.groupby('Actuante_base')
      .agg(
          n_actuaciones=('Actuante', 'nunique'),
          fechas=('fecha', fechas_unicas_str)
      )
      .reset_index()
      .sort_values(['n_actuaciones', 'Actuante_base'], ascending=[False, True])
)

print(tabla.to_string(index=False))
# Out:
#   Actuante_base  n_actuaciones                                                     fechas
#    David Bestué              5 2024-05-06, 2024-10-07, 2025-01-13, 2025-05-19, 2025-11-03
#   Juan Martinez              5 2024-05-06, 2024-10-21, 2025-01-13, 2025-04-07, 2025-11-03
#    Lluis Garcia              5 2024-04-08, 2024-10-21, 2025-01-13, 2025-06-30, 2025-10-06
#  Alexander Main              4             2024-05-27, 2024-10-07, 2025-06-16, 2025-10-06
#  David Valencia              4             2024-07-08, 2024-10-07, 2025-06-30, 2025-10-06
#     Jordi Marti              4             2024-06-17, 2024-10-21, 2025-04-07, 2025-11-03
#         Michele              4             2024-04-08, 2024-11-25, 2025-01-13, 2025-06-30
#  Toni Cachadiña              4             2024-05-27, 2024-11-25, 2025-01-13, 2025-06-16
# Alfredo Alvarez              3                         2024-05-06, 2025-06-30, 2025-11-03
#         Amílcar              3                         2024-07-08, 2024-11-25, 2025-01-13
#   Antonio Reina              3                         2024-07-08, 2025-07-07, 2025-10-20
#    Jaume Cercós              3                         2024-10-07, 2025-01-13, 2025-06-30
#       Luis Egea              3                         2024-07-08, 2025-04-07, 2025-10-20
#            Samu              3                         2024-10-21, 2025-01-13, 2025-06-16
#          Sergio              3                         2024-05-06, 2025-05-19, 2025-10-06
#           Shori              3                         2024-04-08, 2024-10-07, 2025-01-13
#      Xavi Soler              3                         2024-10-07, 2025-07-07, 2025-10-06
#   Alfredo Jauma              2                                     2024-05-27, 2025-06-30
#         Arnau D              2                                     2024-06-17, 2025-05-19
#       Chanisset              2                                     2024-04-08, 2025-05-19
#           Edu A              2                                     2024-05-27, 2025-05-19
#    Ferran Homar              2                                     2024-05-06, 2025-06-16
#           Figno              2                                     2024-07-08, 2024-11-25
#           Gneis              2                                     2025-06-16, 2025-10-20
#      Ivan Padín              2                                     2025-07-07, 2025-10-20
#         Naikari              2                                     2024-05-27, 2024-10-21
#            Olek              2                                     2025-06-16, 2025-10-20
#        Adrián D              1                                                 2025-04-07
#  Albert Farriol              1                                                 2025-05-19
# Albert Farriols              1                                                 2025-11-03
#     Arnau Romeu              1                                                 2025-07-07
#        Carlitos              1                                                 2024-06-17
#        Dani Mir              1                                                 2024-07-08
#    Dani Sanchez              1                                                 2024-04-08
#          Ernest              1                                                 2024-05-27
#            Guti              1                                                 2024-05-27
#           Ismol              1                                                 2025-04-07
#   Javi Martinez              1                                                 2025-07-07
#       Josep M S              1                                                 2024-05-06
#          Miguel              1                                                 2024-07-08
#          Paul H              1                                                 2024-05-06
#        Reinaldo              1                                                 2025-06-30
#           Santy              1                                                 2025-06-16
#            Toni              1                                                 2025-05-19

# %%
# --- lista de actuantes a destacar ---
destacados = ["David Bestué"]  # edítala libremente


# --- Configuración de columnas ---
cols = [
    '¿Qué te ha parecido la imposibilidad del efecto realizado?',
    '¿Qué te han parecido la presentación y la charla?',
    '¿Qué te ha parecido el método?',
    '¿Qué te ha parecido la originalidad del juego?',
    '¿Qué te ha parecido la ejecución del juego?',
    'nota'
]

nombres_cond = [
    'Imposibilidad del efecto',
    'Presentación y charla',
    'Método',
    'Originalidad del juego',
    'Ejecución del juego',
    'Nota ponderada'
]

# --- preparar datos numéricos ---
df_num = df.copy()
for c in cols:
    df_num[c] = pd.to_numeric(df_num[c], errors="coerce")

# --- función para IC95% ---
def ci95(series):
    x = series.dropna()
    n = len(x)
    if n <= 1:
        m = x.mean() if n == 1 else np.nan
        return m, np.nan, np.nan
    m = x.mean()
    h = stats.sem(x) * stats.t.ppf(0.845, n - 1)
    return m, m - h, m + h

# --- estilo ---
sns.set_theme(style="whitegrid", font_scale=1.1)
plt.figure(figsize=(10, 6))

# --- Fondo gris: una línea por actuante (sin IC) ---
for act, sub in df_num.groupby("actuante_original"):
    # medias de cada columna (una por condición)
    medias = [sub[c].mean() for c in cols]
    plt.plot(nombres_cond, medias, color=(0.5, 0.5, 0.5, 0.18), linewidth=1)


# --- Línea negra gruesa con IC69% ---
# Media y error por condición (cols)
means = [df[c].mean() for c in cols]
stds = [df[c].std(ddof=1) for c in cols]
ns = [df[c].count() for c in cols]

# 69% CI: z ≈ 1 (aprox una desviación estándar del error de la media)
z = 1
se = np.array(stds) / np.sqrt(ns)
ci_low = np.array(means) - z * se
ci_high = np.array(means) + z * se

# Dibujar línea y banda
plt.plot(nombres_cond, means, color="black", linewidth=3, marker="o",
         markersize=6, label="Media general")
plt.fill_between(nombres_cond, ci_low, ci_high, color="black", alpha=0.15)



# --- Destacados: color + IC ---
palette = sns.color_palette("tab10", n_colors=max(1, len(destacados)))
handles, labels = [], []

for i, act in enumerate(destacados):
    sub = df_num[df_num["actuante_original"] == act]
    if sub.empty:
        print(f"⚠️ '{act}' no se encontró en actuatne_original; se omite.")
        continue

    medias, low, high = [], [], []
    for c in cols:
        m, l, h = ci95(sub[c])
        medias.append(m)
        low.append(l)
        high.append(h)

    medias = np.array(medias)
    low = np.array(low)
    high = np.array(high)

    h_line, = plt.plot(nombres_cond, medias, color=palette[i],
                       linewidth=2.5, marker="o", label=act)
    plt.fill_between(nombres_cond, low, high, color=palette[i], alpha=0.18)
    handles.append(h_line)
    labels.append(act)

# --- estética general ---
plt.title("Perfil de puntuaciones por condición y actuante", fontsize=15, weight="bold")
plt.xlabel("")
plt.ylabel("Puntuación (1–5)")
plt.ylim(1.5, 5.5)
plt.xticks(rotation=25, ha="right")

if handles:
    plt.legend(handles=handles, labels=labels, title="Actuantes destacados",
               bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
## De una actuación concreta

# %%
# --- Configuración de columnas ---
cols = [
    '¿Qué te ha parecido la imposibilidad del efecto realizado?',
    '¿Qué te han parecido la presentación y la charla?',
    '¿Qué te ha parecido el método?',
    '¿Qué te ha parecido la originalidad del juego?',
    '¿Qué te ha parecido la ejecución del juego?',
    'nota'
]

nombres_cond = [
    'Imposibilidad del efecto',
    'Presentación y charla',
    'Método',
    'Originalidad del juego',
    'Ejecución del juego',
    'Nota ponderada'
]

# --- lista de actuantes a destacar ---
destacados = ["David Bestué", "David Bestué_2", "David Bestué_3", "David Bestué_4", "David Bestué_5"]  # edítala libremente

# --- preparar datos numéricos ---
df_num = df.copy()
for c in cols:
    df_num[c] = pd.to_numeric(df_num[c], errors="coerce")

# --- función para IC95% ---
def ci95(series):
    x = series.dropna()
    n = len(x)
    if n <= 1:
        m = x.mean() if n == 1 else np.nan
        return m, np.nan, np.nan
    m = x.mean()
    h = stats.sem(x) * stats.t.ppf(0.845, n - 1)  ###equivalencia al 69%
    return m, m - h, m + h

# --- estilo ---
sns.set_theme(style="whitegrid", font_scale=1.1)
plt.figure(figsize=(10, 6))

# --- Fondo gris: una línea por actuante (sin IC) ---
for act, sub in df_num.groupby("Actuante"):
    # medias de cada columna (una por condición)
    medias = [sub[c].mean() for c in cols]
    plt.plot(nombres_cond, medias, color=(0.5, 0.5, 0.5, 0.18), linewidth=1)


# --- Línea negra gruesa con IC69% ---
# Media y error por condición (cols)
means = [df[c].mean() for c in cols]
stds = [df[c].std(ddof=1) for c in cols]
ns = [df[c].count() for c in cols]

# 69% CI: z ≈ 1 (aprox una desviación estándar del error de la media)
z = 1
se = np.array(stds) / np.sqrt(ns)
ci_low = np.array(means) - z * se
ci_high = np.array(means) + z * se

# Dibujar línea y banda
plt.plot(nombres_cond, means, color="black", linewidth=3, marker="o",
         markersize=6, label="Media general")
plt.fill_between(nombres_cond, ci_low, ci_high, color="black", alpha=0.15)



# --- Destacados: color + IC ---
palette = sns.color_palette("tab10", n_colors=max(1, len(destacados)))
handles, labels = [], []

for i, act in enumerate(destacados):
    sub = df_num[df_num["Actuante"] == act]
    if sub.empty:
        print(f"⚠️ '{act}' no se encontró en actuatne_original; se omite.")
        continue

    medias, low, high = [], [], []
    for c in cols:
        m, l, h = ci95(sub[c])
        medias.append(m)
        low.append(l)
        high.append(h)

    medias = np.array(medias)
    low = np.array(low)
    high = np.array(high)

    h_line, = plt.plot(nombres_cond, medias, color=palette[i],
                       linewidth=2.5, marker="o", label=act)
    plt.fill_between(nombres_cond, low, high, color=palette[i], alpha=0.18)
    handles.append(h_line)
    labels.append(act)

# --- estética general ---
plt.title("Perfil de puntuaciones por condición y actuación", fontsize=15, weight="bold")
plt.xlabel("")
plt.ylabel("Puntuación (1–5)")
plt.ylim(1.5, 5.5)
plt.xticks(rotation=25, ha="right")

if handles:
    plt.legend(handles=handles, labels=labels, title="Actuación destacada",
               bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Ranking

# %%
#De actuantes

# %%
# Asegurar tipo numérico
df["nota"] = pd.to_numeric(df["nota"], errors="coerce")

# Agrupar por actuante y calcular media + número de actuaciones
ranking = (
    df.groupby("actuante_original")
      .agg(
          nota_media=("nota", "mean"),
          n_actuaciones=("nota", "count")
      )
      .reset_index()
      .sort_values("nota_media", ascending=False)
      .reset_index(drop=True)
)

# Añadir posición en el ranking
ranking["posición"] = ranking.index + 1

# Reordenar columnas para legibilidad
ranking = ranking[["posición", "actuante_original", "nota_media", "n_actuaciones"]]

# Redondear medias a dos decimales
ranking["nota_media"] = ranking["nota_media"].round(2)

# Mostrar resultados
print("🏆 Ranking de actuantes por nota ponderada media:")

display(
    ranking.style
        .hide(axis="index")
        .format({
            "nota_media": "{:.2f}",
            "n_actuaciones": "{:.0f}"
        })
        .set_properties(**{"text-align": "center"})  # centrado opcional
)
# Out:
# 🏆 Ranking de actuantes por nota ponderada media:
# <style type="text/css">
# #T_41594_row0_col0, #T_41594_row0_col1, #T_41594_row0_col2, #T_41594_row0_col3, #T_41594_row1_col0, #T_41594_row1_col1, #T_41594_row1_col2, #T_41594_row1_col3, #T_41594_row2_col0, #T_41594_row2_col1, #T_41594_row2_col2, #T_41594_row2_col3, #T_41594_row3_col0, #T_41594_row3_col1, #T_41594_row3_col2, #T_41594_row3_col3, #T_41594_row4_col0, #T_41594_row4_col1, #T_41594_row4_col2, #T_41594_row4_col3, #T_41594_row5_col0, #T_41594_row5_col1, #T_41594_row5_col2, #T_41594_row5_col3, #T_41594_row6_col0, #T_41594_row6_col1, #T_41594_row6_col2, #T_41594_row6_col3, #T_41594_row7_col0, #T_41594_row7_col1, #T_41594_row7_col2, #T_41594_row7_col3, #T_41594_row8_col0, #T_41594_row8_col1, #T_41594_row8_col2, #T_41594_row8_col3, #T_41594_row9_col0, #T_41594_row9_col1, #T_41594_row9_col2, #T_41594_row9_col3, #T_41594_row10_col0, #T_41594_row10_col1, #T_41594_row10_col2, #T_41594_row10_col3, #T_41594_row11_col0, #T_41594_row11_col1, #T_41594_row11_col2, #T_41594_row11_col3, #T_41594_row12_col0, #T_41594_row12_col1, #T_41594_row12_col2, #T_41594_row12_col3, #T_41594_row13_col0, #T_41594_row13_col1, #T_41594_row13_col2, #T_41594_row13_col3, #T_41594_row14_col0, #T_41594_row14_col1, #T_41594_row14_col2, #T_41594_row14_col3, #T_41594_row15_col0, #T_41594_row15_col1, #T_41594_row15_col2, #T_41594_row15_col3, #T_41594_row16_col0, #T_41594_row16_col1, #T_41594_row16_col2, #T_41594_row16_col3, #T_41594_row17_col0, #T_41594_row17_col1, #T_41594_row17_col2, #T_41594_row17_col3, #T_41594_row18_col0, #T_41594_row18_col1, #T_41594_row18_col2, #T_41594_row18_col3, #T_41594_row19_col0, #T_41594_row19_col1, #T_41594_row19_col2, #T_41594_row19_col3, #T_41594_row20_col0, #T_41594_row20_col1, #T_41594_row20_col2, #T_41594_row20_col3, #T_41594_row21_col0, #T_41594_row21_col1, #T_41594_row21_col2, #T_41594_row21_col3, #T_41594_row22_col0, #T_41594_row22_col1, #T_41594_row22_col2, #T_41594_row22_col3, #T_41594_row23_col0, #T_41594_row23_col1, #T_41594_row23_col2, #T_41594_row23_col3, #T_41594_row24_col0, #T_41594_row24_col1, #T_41594_row24_col2, #T_41594_row24_col3, #T_41594_row25_col0, #T_41594_row25_col1, #T_41594_row25_col2, #T_41594_row25_col3, #T_41594_row26_col0, #T_41594_row26_col1, #T_41594_row26_col2, #T_41594_row26_col3, #T_41594_row27_col0, #T_41594_row27_col1, #T_41594_row27_col2, #T_41594_row27_col3, #T_41594_row28_col0, #T_41594_row28_col1, #T_41594_row28_col2, #T_41594_row28_col3, #T_41594_row29_col0, #T_41594_row29_col1, #T_41594_row29_col2, #T_41594_row29_col3, #T_41594_row30_col0, #T_41594_row30_col1, #T_41594_row30_col2, #T_41594_row30_col3, #T_41594_row31_col0, #T_41594_row31_col1, #T_41594_row31_col2, #T_41594_row31_col3, #T_41594_row32_col0, #T_41594_row32_col1, #T_41594_row32_col2, #T_41594_row32_col3, #T_41594_row33_col0, #T_41594_row33_col1, #T_41594_row33_col2, #T_41594_row33_col3, #T_41594_row34_col0, #T_41594_row34_col1, #T_41594_row34_col2, #T_41594_row34_col3, #T_41594_row35_col0, #T_41594_row35_col1, #T_41594_row35_col2, #T_41594_row35_col3, #T_41594_row36_col0, #T_41594_row36_col1, #T_41594_row36_col2, #T_41594_row36_col3, #T_41594_row37_col0, #T_41594_row37_col1, #T_41594_row37_col2, #T_41594_row37_col3, #T_41594_row38_col0, #T_41594_row38_col1, #T_41594_row38_col2, #T_41594_row38_col3, #T_41594_row39_col0, #T_41594_row39_col1, #T_41594_row39_col2, #T_41594_row39_col3, #T_41594_row40_col0, #T_41594_row40_col1, #T_41594_row40_col2, #T_41594_row40_col3, #T_41594_row41_col0, #T_41594_row41_col1, #T_41594_row41_col2, #T_41594_row41_col3, #T_41594_row42_col0, #T_41594_row42_col1, #T_41594_row42_col2, #T_41594_row42_col3, #T_41594_row43_col0, #T_41594_row43_col1, #T_41594_row43_col2, #T_41594_row43_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_41594">
#   <thead>
#     <tr>
#       <th id="T_41594_level0_col0" class="col_heading level0 col0" >posición</th>
#       <th id="T_41594_level0_col1" class="col_heading level0 col1" >actuante_original</th>
#       <th id="T_41594_level0_col2" class="col_heading level0 col2" >nota_media</th>
#       <th id="T_41594_level0_col3" class="col_heading level0 col3" >n_actuaciones</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_41594_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_41594_row0_col1" class="data row0 col1" >David Bestué</td>
#       <td id="T_41594_row0_col2" class="data row0 col2" >4.25</td>
#       <td id="T_41594_row0_col3" class="data row0 col3" >92</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_41594_row1_col1" class="data row1 col1" >Gneis</td>
#       <td id="T_41594_row1_col2" class="data row1 col2" >4.19</td>
#       <td id="T_41594_row1_col3" class="data row1 col3" >34</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_41594_row2_col1" class="data row2 col1" >Paul H</td>
#       <td id="T_41594_row2_col2" class="data row2 col2" >4.11</td>
#       <td id="T_41594_row2_col3" class="data row2 col3" >16</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_41594_row3_col1" class="data row3 col1" >Amílcar</td>
#       <td id="T_41594_row3_col2" class="data row3 col2" >4.03</td>
#       <td id="T_41594_row3_col3" class="data row3 col3" >45</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_41594_row4_col1" class="data row4 col1" >Michele</td>
#       <td id="T_41594_row4_col2" class="data row4 col2" >4.03</td>
#       <td id="T_41594_row4_col3" class="data row4 col3" >68</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_41594_row5_col1" class="data row5 col1" >Ivan Padín</td>
#       <td id="T_41594_row5_col2" class="data row5 col2" >3.98</td>
#       <td id="T_41594_row5_col3" class="data row5 col3" >39</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_41594_row6_col1" class="data row6 col1" >Alfredo Alvarez</td>
#       <td id="T_41594_row6_col2" class="data row6 col2" >3.98</td>
#       <td id="T_41594_row6_col3" class="data row6 col3" >43</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_41594_row7_col1" class="data row7 col1" >Juan Martinez</td>
#       <td id="T_41594_row7_col2" class="data row7 col2" >3.87</td>
#       <td id="T_41594_row7_col3" class="data row7 col3" >83</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_41594_row8_col1" class="data row8 col1" >Shori</td>
#       <td id="T_41594_row8_col2" class="data row8 col2" >3.85</td>
#       <td id="T_41594_row8_col3" class="data row8 col3" >62</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_41594_row9_col1" class="data row9 col1" >Alexander Main</td>
#       <td id="T_41594_row9_col2" class="data row9 col2" >3.83</td>
#       <td id="T_41594_row9_col3" class="data row9 col3" >67</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_41594_row10_col1" class="data row10 col1" >Carlitos</td>
#       <td id="T_41594_row10_col2" class="data row10 col2" >3.82</td>
#       <td id="T_41594_row10_col3" class="data row10 col3" >14</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_41594_row11_col1" class="data row11 col1" >Lluis Garcia</td>
#       <td id="T_41594_row11_col2" class="data row11 col2" >3.81</td>
#       <td id="T_41594_row11_col3" class="data row11 col3" >88</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_41594_row12_col1" class="data row12 col1" >Naikari</td>
#       <td id="T_41594_row12_col2" class="data row12 col2" >3.80</td>
#       <td id="T_41594_row12_col3" class="data row12 col3" >29</td>
#     </tr>
#     <tr>
#       <td id="T_41594_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_41594_row13_col1

# %%
# De actuaciones
df["nota"] = pd.to_numeric(df["nota"], errors="coerce")

# Agrupar por actuante y calcular media + número de actuaciones
ranking = (
    df.groupby("Actuante")
      .agg(
          nota_media=("nota", "mean"),
          n_actuaciones=("nota", "count")
      )
      .reset_index()
      .sort_values("nota_media", ascending=False)
      .reset_index(drop=True)
)

# Añadir posición en el ranking
ranking["posición"] = ranking.index + 1

# Reordenar columnas para legibilidad
ranking = ranking[["posición", "Actuante", "nota_media", "n_actuaciones"]]

# Redondear medias a dos decimales
ranking["nota_media"] = ranking["nota_media"].round(2)

# Mostrar resultados
print("🏆 Ranking de actuanciones por nota ponderada media:")

display(
    ranking.style
        .hide(axis="index")
        .format({
            "nota_media": "{:.2f}",
            "n_actuaciones": "{:.0f}"
        })
        .set_properties(**{"text-align": "center"})  # centrado opcional
)
# Out:
# 🏆 Ranking de actuanciones por nota ponderada media:
# <style type="text/css">
# #T_647e0_row0_col0, #T_647e0_row0_col1, #T_647e0_row0_col2, #T_647e0_row0_col3, #T_647e0_row1_col0, #T_647e0_row1_col1, #T_647e0_row1_col2, #T_647e0_row1_col3, #T_647e0_row2_col0, #T_647e0_row2_col1, #T_647e0_row2_col2, #T_647e0_row2_col3, #T_647e0_row3_col0, #T_647e0_row3_col1, #T_647e0_row3_col2, #T_647e0_row3_col3, #T_647e0_row4_col0, #T_647e0_row4_col1, #T_647e0_row4_col2, #T_647e0_row4_col3, #T_647e0_row5_col0, #T_647e0_row5_col1, #T_647e0_row5_col2, #T_647e0_row5_col3, #T_647e0_row6_col0, #T_647e0_row6_col1, #T_647e0_row6_col2, #T_647e0_row6_col3, #T_647e0_row7_col0, #T_647e0_row7_col1, #T_647e0_row7_col2, #T_647e0_row7_col3, #T_647e0_row8_col0, #T_647e0_row8_col1, #T_647e0_row8_col2, #T_647e0_row8_col3, #T_647e0_row9_col0, #T_647e0_row9_col1, #T_647e0_row9_col2, #T_647e0_row9_col3, #T_647e0_row10_col0, #T_647e0_row10_col1, #T_647e0_row10_col2, #T_647e0_row10_col3, #T_647e0_row11_col0, #T_647e0_row11_col1, #T_647e0_row11_col2, #T_647e0_row11_col3, #T_647e0_row12_col0, #T_647e0_row12_col1, #T_647e0_row12_col2, #T_647e0_row12_col3, #T_647e0_row13_col0, #T_647e0_row13_col1, #T_647e0_row13_col2, #T_647e0_row13_col3, #T_647e0_row14_col0, #T_647e0_row14_col1, #T_647e0_row14_col2, #T_647e0_row14_col3, #T_647e0_row15_col0, #T_647e0_row15_col1, #T_647e0_row15_col2, #T_647e0_row15_col3, #T_647e0_row16_col0, #T_647e0_row16_col1, #T_647e0_row16_col2, #T_647e0_row16_col3, #T_647e0_row17_col0, #T_647e0_row17_col1, #T_647e0_row17_col2, #T_647e0_row17_col3, #T_647e0_row18_col0, #T_647e0_row18_col1, #T_647e0_row18_col2, #T_647e0_row18_col3, #T_647e0_row19_col0, #T_647e0_row19_col1, #T_647e0_row19_col2, #T_647e0_row19_col3, #T_647e0_row20_col0, #T_647e0_row20_col1, #T_647e0_row20_col2, #T_647e0_row20_col3, #T_647e0_row21_col0, #T_647e0_row21_col1, #T_647e0_row21_col2, #T_647e0_row21_col3, #T_647e0_row22_col0, #T_647e0_row22_col1, #T_647e0_row22_col2, #T_647e0_row22_col3, #T_647e0_row23_col0, #T_647e0_row23_col1, #T_647e0_row23_col2, #T_647e0_row23_col3, #T_647e0_row24_col0, #T_647e0_row24_col1, #T_647e0_row24_col2, #T_647e0_row24_col3, #T_647e0_row25_col0, #T_647e0_row25_col1, #T_647e0_row25_col2, #T_647e0_row25_col3, #T_647e0_row26_col0, #T_647e0_row26_col1, #T_647e0_row26_col2, #T_647e0_row26_col3, #T_647e0_row27_col0, #T_647e0_row27_col1, #T_647e0_row27_col2, #T_647e0_row27_col3, #T_647e0_row28_col0, #T_647e0_row28_col1, #T_647e0_row28_col2, #T_647e0_row28_col3, #T_647e0_row29_col0, #T_647e0_row29_col1, #T_647e0_row29_col2, #T_647e0_row29_col3, #T_647e0_row30_col0, #T_647e0_row30_col1, #T_647e0_row30_col2, #T_647e0_row30_col3, #T_647e0_row31_col0, #T_647e0_row31_col1, #T_647e0_row31_col2, #T_647e0_row31_col3, #T_647e0_row32_col0, #T_647e0_row32_col1, #T_647e0_row32_col2, #T_647e0_row32_col3, #T_647e0_row33_col0, #T_647e0_row33_col1, #T_647e0_row33_col2, #T_647e0_row33_col3, #T_647e0_row34_col0, #T_647e0_row34_col1, #T_647e0_row34_col2, #T_647e0_row34_col3, #T_647e0_row35_col0, #T_647e0_row35_col1, #T_647e0_row35_col2, #T_647e0_row35_col3, #T_647e0_row36_col0, #T_647e0_row36_col1, #T_647e0_row36_col2, #T_647e0_row36_col3, #T_647e0_row37_col0, #T_647e0_row37_col1, #T_647e0_row37_col2, #T_647e0_row37_col3, #T_647e0_row38_col0, #T_647e0_row38_col1, #T_647e0_row38_col2, #T_647e0_row38_col3, #T_647e0_row39_col0, #T_647e0_row39_col1, #T_647e0_row39_col2, #T_647e0_row39_col3, #T_647e0_row40_col0, #T_647e0_row40_col1, #T_647e0_row40_col2, #T_647e0_row40_col3, #T_647e0_row41_col0, #T_647e0_row41_col1, #T_647e0_row41_col2, #T_647e0_row41_col3, #T_647e0_row42_col0, #T_647e0_row42_col1, #T_647e0_row42_col2, #T_647e0_row42_col3, #T_647e0_row43_col0, #T_647e0_row43_col1, #T_647e0_row43_col2, #T_647e0_row43_col3, #T_647e0_row44_col0, #T_647e0_row44_col1, #T_647e0_row44_col2, #T_647e0_row44_col3, #T_647e0_row45_col0, #T_647e0_row45_col1, #T_647e0_row45_col2, #T_647e0_row45_col3, #T_647e0_row46_col0, #T_647e0_row46_col1, #T_647e0_row46_col2, #T_647e0_row46_col3, #T_647e0_row47_col0, #T_647e0_row47_col1, #T_647e0_row47_col2, #T_647e0_row47_col3, #T_647e0 ...

# %%
### Ranking de 5 en cada categoría

# %%
df.head()
# Out:
#           fecha Actuante  \
# 118  2024-04-08  Michele
# 119  2024-04-08  Michele
# 120  2024-04-08  Michele
# 121  2024-04-08  Michele
# 122  2024-04-08  Michele
#
#      ¿Qué te ha parecido la imposibilidad del efecto realizado?  \
# 118                                                  3
# 119                                                  4
# 120                                                  4
# 121                                                  4
# 122                                                  4
#
#      ¿Qué te han parecido la presentación y la charla?  \
# 118                                                  3
# 119                                                  4
# 120                                                  3
# 121                                                  4
# 122                                                  3
#
#      ¿Qué te ha parecido el método?  \
# 118                               2
# 119                               4
# 120                               3
# 121                               4
# 122                               4
#
#      ¿Qué te ha parecido la originalidad del juego?  \
# 118                                               3
# 119                                               4
# 120                                               4
# 121                                               4
# 122                                               3
#
#      ¿Qué te ha parecido la ejecución del juego? actuante_original  nota  \
# 118                                            4           Michele   3.1
# 119                                            4           Michele   4.0
# 120                                            3           Michele   3.4
# 121                                            4           Michele   4.0
# 122                                            3           Michele   3.4
#
#     Actuante_base
# 118       Michele
# 119       Michele
# 120       Michele
# 121       Michele
# 122       Michele

# %%
df.columns
# Out:
# Index(['fecha', 'Actuante',
#        '¿Qué te ha parecido la imposibilidad del efecto realizado?',
#        '¿Qué te han parecido la presentación y la charla?',
#        '¿Qué te ha parecido el método?',
#        '¿Qué te ha parecido la originalidad del juego?',
#        '¿Qué te ha parecido la ejecución del juego?', 'actuante_original',
#        'nota', 'Actuante_base'],
#       dtype='object')

# %%
criterios = [ '¿Qué te ha parecido la imposibilidad del efecto realizado?',
       '¿Qué te han parecido la presentación y la charla?',
       '¿Qué te ha parecido el método?',
       '¿Qué te ha parecido la originalidad del juego?',
       '¿Qué te ha parecido la ejecución del juego?']

criterios_title = ['Imposibilidad', 'Presentación', 'Método', 'Originalidad', 'Ejecución']

# %%
# Asegurar tipo numérico
df["nota"] = pd.to_numeric(df["nota"], errors="coerce")


for cr, criterio in enumerate(criterios):
    # Agrupar por actuante y calcular media + número de actuaciones
    ranking = (
        df.groupby("actuante_original")
          .agg(
              nota_media=(criterios[cr], "mean"),
              n_actuaciones=(criterios[cr], "count")
          )
          .reset_index()
          .sort_values("nota_media", ascending=False)
          .reset_index(drop=True)
    )

    # Añadir posición en el ranking
    ranking["posición"] = ranking.index + 1

    # Reordenar columnas para legibilidad
    ranking = ranking[["posición", "actuante_original", "nota_media", "n_actuaciones"]]

    # Redondear medias a dos decimales
    ranking["nota_media"] = ranking["nota_media"].round(2)

    ranking_5 = ranking.iloc[:5, :]

    # Mostrar resultados
    print("🏆 Ranking de " + criterios_title[cr] + ":")

    display(
        ranking_5.style
            .hide(axis="index")
            .format({
                "nota_media": "{:.2f}",
                "n_actuaciones": "{:.0f}"
            })
            .set_properties(**{"text-align": "center"})  # centrado opcional
    )
# Out:
# 🏆 Ranking de Imposibilidad:
# <style type="text/css">
# #T_c8a73_row0_col0, #T_c8a73_row0_col1, #T_c8a73_row0_col2, #T_c8a73_row0_col3, #T_c8a73_row1_col0, #T_c8a73_row1_col1, #T_c8a73_row1_col2, #T_c8a73_row1_col3, #T_c8a73_row2_col0, #T_c8a73_row2_col1, #T_c8a73_row2_col2, #T_c8a73_row2_col3, #T_c8a73_row3_col0, #T_c8a73_row3_col1, #T_c8a73_row3_col2, #T_c8a73_row3_col3, #T_c8a73_row4_col0, #T_c8a73_row4_col1, #T_c8a73_row4_col2, #T_c8a73_row4_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_c8a73">
#   <thead>
#     <tr>
#       <th id="T_c8a73_level0_col0" class="col_heading level0 col0" >posición</th>
#       <th id="T_c8a73_level0_col1" class="col_heading level0 col1" >actuante_original</th>
#       <th id="T_c8a73_level0_col2" class="col_heading level0 col2" >nota_media</th>
#       <th id="T_c8a73_level0_col3" class="col_heading level0 col3" >n_actuaciones</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c8a73_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c8a73_row0_col1" class="data row0 col1" >David Bestué</td>
#       <td id="T_c8a73_row0_col2" class="data row0 col2" >4.39</td>
#       <td id="T_c8a73_row0_col3" class="data row0 col3" >92</td>
#     </tr>
#     <tr>
#       <td id="T_c8a73_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_c8a73_row1_col1" class="data row1 col1" >Michele</td>
#       <td id="T_c8a73_row1_col2" class="data row1 col2" >4.28</td>
#       <td id="T_c8a73_row1_col3" class="data row1 col3" >68</td>
#     </tr>
#     <tr>
#       <td id="T_c8a73_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_c8a73_row2_col1" class="data row2 col1" >Alfredo Alvarez</td>
#       <td id="T_c8a73_row2_col2" class="data row2 col2" >4.23</td>
#       <td id="T_c8a73_row2_col3" class="data row2 col3" >43</td>
#     </tr>
#     <tr>
#       <td id="T_c8a73_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_c8a73_row3_col1" class="data row3 col1" >Amílcar</td>
#       <td id="T_c8a73_row3_col2" class="data row3 col2" >4.16</td>
#       <td id="T_c8a73_row3_col3" class="data row3 col3" >45</td>
#     </tr>
#     <tr>
#       <td id="T_c8a73_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_c8a73_row4_col1" class="data row4 col1" >Shori</td>
#       <td id="T_c8a73_row4_col2" class="data row4 col2" >4.08</td>
#       <td id="T_c8a73_row4_col3" class="data row4 col3" >62</td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Ranking de Presentación:
# <style type="text/css">
# #T_915cf_row0_col0, #T_915cf_row0_col1, #T_915cf_row0_col2, #T_915cf_row0_col3, #T_915cf_row1_col0, #T_915cf_row1_col1, #T_915cf_row1_col2, #T_915cf_row1_col3, #T_915cf_row2_col0, #T_915cf_row2_col1, #T_915cf_row2_col2, #T_915cf_row2_col3, #T_915cf_row3_col0, #T_915cf_row3_col1, #T_915cf_row3_col2, #T_915cf_row3_col3, #T_915cf_row4_col0, #T_915cf_row4_col1, #T_915cf_row4_col2, #T_915cf_row4_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_915cf">
#   <thead>
#     <tr>
#       <th id="T_915cf_level0_col0" class="col_heading level0 col0" >posición</th>
#       <th id="T_915cf_level0_col1" class="col_heading level0 col1" >actuante_original</th>
#       <th id="T_915cf_level0_col2" class="col_heading level0 col2" >nota_media</th>
#       <th id="T_915cf_level0_col3" class="col_heading level0 col3" >n_actuaciones</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_915cf_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_915cf_row0_col1" class="data row0 col1" >Gneis</td>
#       <td id="T_915cf_row0_col2" class="data row0 col2" >4.62</td>
#       <td id="T_915cf_row0_col3" class="data row0 col3" >34</td>
#     </tr>
#     <tr>
#       <td id="T_915cf_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_915cf_row1_col1" class="data row1 col1" >Paul H</td>
#       <td id="T_915cf_row1_col2" class="data row1 col2" >4.19</td>
#       <td id="T_915cf_row1_col3" class="data row1 col3" >16</td>
#     </tr>
#     <tr>
#       <td id="T_915cf_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_915cf_row2_col1" class="data row2 col1" >Lluis Garcia</td>
#       <td id="T_915cf_row2_col2" class="data row2 col2" >4.12</td>
#       <td id="T_915cf_row2_col3" class="data row2 col3" >88</td>
#     </tr>
#     <tr>
#       <td id="T_915cf_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_915cf_row3_col1" class="data row3 col1" >David Bestué</td>
#       <td id="T_915cf_row3_col2" class="data row3 col2" >4.11</td>
#       <td id="T_915cf_row3_col3" class="data row3 col3" >92</td>
#     </tr>
#     <tr>
#       <td id="T_915cf_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_915cf_row4_col1" class="data row4 col1" >Michele</td>
#       <td id="T_915cf_row4_col2" class="data row4 col2" >4.00</td>
#       <td id="T_915cf_row4_col3" class="data row4 col3" >68</td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Ranking de Método:
# <style type="text/css">
# #T_a77b0_row0_col0, #T_a77b0_row0_col1, #T_a77b0_row0_col2, #T_a77b0_row0_col3, #T_a77b0_row1_col0, #T_a77b0_row1_col1, #T_a77b0_row1_col2, #T_a77b0_row1_col3, #T_a77b0_row2_col0, #T_a77b0_row2_col1, #T_a77b0_row2_col2, #T_a77b0_row2_col3, #T_a77b0_row3_col0, #T_a77b0_row3_col1, #T_a77b0_row3_col2, #T_a77b0_row3_col3, #T_a77b0_row4_col0, #T_a77b0_row4_col1, #T_a77b0_row4_col2, #T_a77b0_row4_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_a77b0">
#   <thead>
#     <tr>
#       <th id="T_a77b0_level0_col0" class="col_heading level0 col0" >posición</th>
#       <th id="T_a77b0_level0_col1" class="col_heading level0 col1" >actuante_original</th>
#       <th id="T_a77b0_level0_col2" class="col_heading level0 col2" >nota_media</th>
#       <th id="T_a77b0_level0_col3" class="col_heading level0 col3" >n_actuaciones</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a77b0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a77b0_row0_col1" class="data row0 col1" >David Bestué</td>
#       <td id="T_a77b0_row0_col2" class="data row0 col2" >4.32</td>
#       <td id="T_a77b0_row0_col3" class="data row0 col3" >92</td>
#     </tr>
#     <tr>
#       <td id="T_a77b0_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a77b0_row1_col1" class="data row1 col1" >Alfredo Alvarez</td>
#       <td id="T_a77b0_row1_col2" class="data row1 col2" >4.26</td>
#       <td id="T_a77b0_row1_col3" class="data row1 col3" >43</td>
#     </tr>
#     <tr>
#       <td id="T_a77b0_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a77b0_row2_col1" class="data row2 col1" >Amílcar</td>
#       <td id="T_a77b0_row2_col2" class="data row2 col2" >4.13</td>
#       <td id="T_a77b0_row2_col3" class="data row2 col3" >45</td>
#     </tr>
#     <tr>
#       <td id="T_a77b0_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a77b0_row3_col1" class="data row3 col1" >Paul H</td>
#       <td id="T_a77b0_row3_col2" class="data row3 col2" >4.06</td>
#       <td id="T_a77b0_row3_col3" class="data row3 col3" >16</td>
#     </tr>
#     <tr>
#       <td id="T_a77b0_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a77b0_row4_col1" class="data row4 col1" >Dani Sanchez</td>
#       <td id="T_a77b0_row4_col2" class="data row4 col2" >4.00</td>
#       <td id="T_a77b0_row4_col3" class="data row4 col3" >23</td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Ranking de Originalidad:
# <style type="text/css">
# #T_e031f_row0_col0, #T_e031f_row0_col1, #T_e031f_row0_col2, #T_e031f_row0_col3, #T_e031f_row1_col0, #T_e031f_row1_col1, #T_e031f_row1_col2, #T_e031f_row1_col3, #T_e031f_row2_col0, #T_e031f_row2_col1, #T_e031f_row2_col2, #T_e031f_row2_col3, #T_e031f_row3_col0, #T_e031f_row3_col1, #T_e031f_row3_col2, #T_e031f_row3_col3, #T_e031f_row4_col0, #T_e031f_row4_col1, #T_e031f_row4_col2, #T_e031f_row4_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_e031f">
#   <thead>
#     <tr>
#       <th id="T_e031f_level0_col0" class="col_heading level0 col0" >posición</th>
#       <th id="T_e031f_level0_col1" class="col_heading level0 col1" >actuante_original</th>
#       <th id="T_e031f_level0_col2" class="col_heading level0 col2" >nota_media</th>
#       <th id="T_e031f_level0_col3" class="col_heading level0 col3" >n_actuaciones</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e031f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e031f_row0_col1" class="data row0 col1" >Carlitos</td>
#       <td id="T_e031f_row0_col2" class="data row0 col2" >4.43</td>
#       <td id="T_e031f_row0_col3" class="data row0 col3" >14</td>
#     </tr>
#     <tr>
#       <td id="T_e031f_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e031f_row1_col1" class="data row1 col1" >Paul H</td>
#       <td id="T_e031f_row1_col2" class="data row1 col2" >4.06</td>
#       <td id="T_e031f_row1_col3" class="data row1 col3" >16</td>
#     </tr>
#     <tr>
#       <td id="T_e031f_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e031f_row2_col1" class="data row2 col1" >Ivan Padín</td>
#       <td id="T_e031f_row2_col2" class="data row2 col2" >4.00</td>
#       <td id="T_e031f_row2_col3" class="data row2 col3" >39</td>
#     </tr>
#     <tr>
#       <td id="T_e031f_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e031f_row3_col1" class="data row3 col1" >David Bestué</td>
#       <td id="T_e031f_row3_col2" class="data row3 col2" >3.95</td>
#       <td id="T_e031f_row3_col3" class="data row3 col3" >92</td>
#     </tr>
#     <tr>
#       <td id="T_e031f_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_e031f_row4_col1" class="data row4 col1" >Juan Martinez</td>
#       <td id="T_e031f_row4_col2" class="data row4 col2" >3.86</td>
#       <td id="T_e031f_row4_col3" class="data row4 col3" >83</td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Ranking de Ejecución:
# <style type="text/css">
# #T_45fba_row0_col0, #T_45fba_row0_col1, #T_45fba_row0_col2, #T_45fba_row0_col3, #T_45fba_row1_col0, #T_45fba_row1_col1, #T_45fba_row1_col2, #T_45fba_row1_col3, #T_45fba_row2_col0, #T_45fba_row2_col1, #T_45fba_row2_col2, #T_45fba_row2_col3, #T_45fba_row3_col0, #T_45fba_row3_col1, #T_45fba_row3_col2, #T_45fba_row3_col3, #T_45fba_row4_col0, #T_45fba_row4_col1, #T_45fba_row4_col2, #T_45fba_row4_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_45fba">
#   <thead>
#     <tr>
#       <th id="T_45fba_level0_col0" class="col_heading level0 col0" >posición</th>
#       <th id="T_45fba_level0_col1" class="col_heading level0 col1" >actuante_original</th>
#       <th id="T_45fba_level0_col2" class="col_heading level0 col2" >nota_media</th>
#       <th id="T_45fba_level0_col3" class="col_heading level0 col3" >n_actuaciones</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_45fba_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_45fba_row0_col1" class="data row0 col1" >Gneis</td>
#       <td id="T_45fba_row0_col2" class="data row0 col2" >4.44</td>
#       <td id="T_45fba_row0_col3" class="data row0 col3" >34</td>
#     </tr>
#     <tr>
#       <td id="T_45fba_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_45fba_row1_col1" class="data row1 col1" >David Bestué</td>
#       <td id="T_45fba_row1_col2" class="data row1 col2" >4.39</td>
#       <td id="T_45fba_row1_col3" class="data row1 col3" >92</td>
#     </tr>
#     <tr>
#       <td id="T_45fba_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_45fba_row2_col1" class="data row2 col1" >Alfredo Alvarez</td>
#       <td id="T_45fba_row2_col2" class="data row2 col2" >4.35</td>
#       <td id="T_45fba_row2_col3" class="data row2 col3" >43</td>
#     </tr>
#     <tr>
#       <td id="T_45fba_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_45fba_row3_col1" class="data row3 col1" >Dani Sanchez</td>
#       <td id="T_45fba_row3_col2" class="data row3 col2" >4.30</td>
#       <td id="T_45fba_row3_col3" class="data row3 col3" >23</td>
#     </tr>
#     <tr>
#       <td id="T_45fba_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_45fba_row4_col1" class="data row4 col1" >Amílcar</td>
#       <td id="T_45fba_row4_col2" class="data row4 col2" >4.22</td>
#       <td id="T_45fba_row4_col3" class="data row4 col3" >45</td>
#     </tr>
#   </tbody>
# </table>
